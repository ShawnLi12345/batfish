# %% [markdown]
# # New Questions Test Notebook

# %%
# Importing required libraries, setting up logging, and loading questions
import logging
import random  # noqa: F401
from typing import List, Optional  # noqa: F401

import pandas as pd
from IPython.display import display
from pandas.io.formats.style import Styler

from pybatfish.client.session import Session  # noqa: F401

# noinspection PyUnresolvedReferences
from pybatfish.datamodel import Edge, Interface  # noqa: F401
from pybatfish.datamodel.answer import TableAnswer
from pybatfish.datamodel.flow import HeaderConstraints, PathConstraints  # noqa: F401
from pybatfish.datamodel.route import BgpRoute  # noqa: F401
from pybatfish.util import get_html

# Configure all pybatfish loggers to use WARN level
logging.getLogger("pybatfish").setLevel(logging.WARN)

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)
# Prevent rendering text between '$' as MathJax expressions
pd.set_option("display.html.use_mathjax", False)

# UUID for CSS styles used by pandas styler.
# Keeps our notebook HTML deterministic when displaying dataframes
_STYLE_UUID = "pybfstyle"


class MyStyler(Styler):
    """A custom styler for displaying DataFrames in HTML"""

    def __repr__(self):
        return repr(self.data)


def show(df):
    """
    Displays a dataframe as HTML table.

    Replaces newlines and double-spaces in the input with HTML markup, and
    left-aligns the text.
    """
    if isinstance(df, TableAnswer):
        df = df.frame()

    # workaround for Pandas bug in Python 2.7 for empty frames
    if not isinstance(df, pd.DataFrame) or df.size == 0:
        display(df)
        return
    display(
        MyStyler(df)
        .set_uuid(_STYLE_UUID)
        .format(get_html)
        .set_properties(**{"text-align": "left", "vertical-align": "top"})
    )

# %%
bf = Session(host="localhost")

# %% [markdown]
# ## Load a network snapshot

# %%
NETWORK_NAME = "internet2"
SNAPSHOT_PATH = r"\config2spec\scenarios\internet2"  
# change this to your snapshot path

bf.set_network(NETWORK_NAME)
bf.init_snapshot(SNAPSHOT_PATH, name="snapshot")
# Out:
# 'snapshot'

# %% [markdown]
# ## CommunityMatchUsage
# Lists number of community match expressions each node uses.

# %%
result = bf.q.communityMatchUsage().answer().frame()
result
# Out:
#        Node Community_Match_Count
# 0  atla-re0                    72
# 1  chic-re0                   189
# 2  clev-re0                    58
# 3  hous-re0                    64
# 4  kans-re0                    76
# 5  losa-re0                   357
# 6  newy-re0                   163
# 7  salt-re0                    74
# 8  seat-re0                   155
# 9  wash-re0                   163

# %% [markdown]
# ## CommunityReferences
# Lists community match expressions and the nodes that reference them.

# %%
result = bf.q.communityReferences().answer().frame()
result
# Out:
#                       Community  \
# 0                     ALL-COMMS
# 1           BLOCK-TO-COMMERCIAL
# 2             BLOCK-TO-EXTERNAL
# 3                     CLEARSPAN
# 4    CLEAR_COMMUNITIES_FROMCUST
# ..                          ...
# 574                 TRMIGRATION
# 575             TRMIGRATION-GPN
# 576        WILDCARD-ANY-AS11164
# 577                    ion-test
# 578                  ion-test-b
#
#                                                                                                                     Node_List  \
# 0                                        ['chic-re0', 'clev-re0', 'losa-re0', 'newy-re0', 'salt-re0', 'seat-re0', 'wash-re0']
# 1    ['atla-re0', 'chic-re0', 'clev-re0', 'hous-re0', 'kans-re0', 'losa-re0', 'newy-re0', 'salt-re0', 'seat-re0', 'wash-re0']
# 2    ['atla-re0', 'chic-re0', 'clev-re0', 'hous-re0', 'kans-re0', 'losa-re0', 'newy-re0', 'salt-re0', 'seat-re0', 'wash-re0']
# ...

# %% [markdown]
# ## RouteFilterUsers
# Lists number of route filters each node uses.

# %%
result = bf.q.routeFilterUsers().answer().frame()
result
# Out:
#        Node Route_Filter_Count
# 0  atla-re0                143
# 1  chic-re0                300
# 2  clev-re0                125
# 3  hous-re0                153
# 4  kans-re0                178
# 5  losa-re0                171
# 6  newy-re0                185
# 7  salt-re0                102
# 8  seat-re0                140
# 9  wash-re0                256

# %% [markdown]
# ## TiebreakerUsage
# Lists the BGP tiebreaker used by each node.

# %%
result = bf.q.tiebreakerUsage().answer().frame()
result
# Out:
#       Tiebreaker  \
# 0  ARRIVAL_ORDER
#
#                                                                                                                   Node_List  \
# 0  ['atla-re0', 'chic-re0', 'clev-re0', 'hous-re0', 'kans-re0', 'losa-re0', 'newy-re0', 'salt-re0', 'seat-re0', 'wash-re0']
#
#   Node_Count
# 0         10

# %% [markdown]
# ## MultipathMatchUsage
# Lists nodes by their multipath match mode. Nodes without both EBGP and IBGP multipath enabled are grouped under N/A.

# %%
result = bf.q.multipathMatchUsage().answer().frame()
result
# Out:
#   Match_Mode  \
# 0        N/A
#
#                                                                                                                   Node_List  \
# 0  ['atla-re0', 'chic-re0', 'clev-re0', 'hous-re0', 'kans-re0', 'losa-re0', 'newy-re0', 'salt-re0', 'seat-re0', 'wash-re0']
#
#   Node_Count
# 0         10

# %% [markdown]
# ## AsPathUsage
# Lists AS paths and the nodes that have routes using that path.

# %%
result = bf.q.asPathUsage().answer().frame()
result
# Out:
# ---------------------------------------------------------------------------
# BatfishException                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 result = bf.q.asPathUsage().answer().frame()
#       2 result
#
# File d:\Cubie\ucla\net\.venv\Lib\site-packages\pybatfish\question\question.py:181, in QuestionBase.answer(self, snapshot, reference_snapshot, include_one_table_keys, background, extra_args)
#     179 if include_one_table_keys is not None:
#     180     self._set_include_one_table_keys(include_one_table_keys)
# --> 181 return _bf_answer_obj(
#     182     session=session,
#     183     question_str=self.json(),
#     184     question_name=self.get_name(),
#     185     background=background,
#     186     snapshot=real_snapshot,
#     187     reference_snapshot=reference_snapshot,
#     188     extra_args=extra_args,
#     189 )
#
# ...

# %% [markdown]
# ## BgpPropertiesCount
# Counts BGP process properties across nodes.

# %%
result = bf.q.bgpPropertiesCount().answer().frame()
result
# Out:
#                   Node_Structure_Name Community_Set_Vals Set_Metric  \
# 0      atla-re0 AL2S-IN-INBAND-BACKUP                  0          0
# 1     atla-re0 AL2S-IN-INBAND-PRIMARY                  0          0
# 2         atla-re0 AL2S-IN-OOB-BACKUP                  0          0
# 3        atla-re0 AL2S-IN-OOB-PRIMARY                  0          0
# 4     atla-re0 AL2S-OUT-INBAND-BACKUP                  0          0
# ...                               ...                ...        ...
# 1514           wash-re0 WORLDBANK-IN6                  0          0
# 1515                  wash-re0 WSU-IN                  0          0
# 1516                wash-re0 ion-test                  0          0
# 1517   wash-re0 load-balancing-policy                  0          0
# 1518         wash-re0 pim-join-filter                  0          0
#
#      Match_Community_Vals Local_Preference
# 0                       0                1
# 1                       0                1
# ...

# %% [markdown]
# ## CommunitySetRegex
# Lists community set match expression names and corresponding regular expressions.

# %%
result = bf.q.communitySetRegex().answer().frame()
result
# Out:
#                  Structure_Name                    Regex
# 0                     ALL-COMMS                    .*:.*
# 1    CLEAR_COMMUNITIES_FROMCUST         ^11164:[1,7-9]*$
# 2               CPS-AS10310-OUT                 .*:10310
# 3               CPS-AS11164-OUT                 .*:11164
# 4               CPS-AS11274-OUT                 .*:11274
# ..                          ...                      ...
# 248            NETPLUS-PREPEND2                 65002:.*
# 249            NETPLUS-PREPEND3                 65003:.*
# 250                TO-CPS-PEERS  ^11164:((7880)|(7890))$
# 251            TRCPS_WASH_19782            65000:19782:1
# 252        WILDCARD-ANY-AS11164             ^11164:(.*)$
#
# [253 rows x 2 columns]

# %% [markdown]
# ## SubnetworkPolicies
# Lists routing policies between routers within a subnetwork.

# %%
result = bf.q.subnetworkPolicies().answer().frame()
result
# Out:
#        Node    Policy_Name            Policy_Type  \
# 0  atla-re0  NEXT-HOP-SELF  Export_Routing_Policy
# 1  chic-re0  NEXT-HOP-SELF  Export_Routing_Policy
# 2  clev-re0  NEXT-HOP-SELF  Export_Routing_Policy
# 3  hous-re0  NEXT-HOP-SELF  Export_Routing_Policy
# 4  kans-re0  NEXT-HOP-SELF  Export_Routing_Policy
# 5  losa-re0  NEXT-HOP-SELF  Export_Routing_Policy
# 6  newy-re0  NEXT-HOP-SELF  Export_Routing_Policy
# 7  salt-re0  NEXT-HOP-SELF  Export_Routing_Policy
# 8  seat-re0  NEXT-HOP-SELF  Export_Routing_Policy
# 9  wash-re0  NEXT-HOP-SELF  Export_Routing_Policy
#
# ...

# %% [markdown]
# ## SubnetworkPolicyMetrics
# Counts BGP properties in routing policies between routers within a subnetwork.

# %%
result = bf.q.subnetworkPolicyMetrics().answer().frame()
result
# Out:
#                Node_Policy Community_Set_Vals Set_Metric Match_Community_Vals  \
# 0   atla-re0 NEXT-HOP-SELF                  0          0                    0
# 1   chic-re0 NEXT-HOP-SELF                  0          0                    0
# 2   clev-re0 NEXT-HOP-SELF                  0          0                    0
# 3   hous-re0 NEXT-HOP-SELF                  0          0                    0
# 4   kans-re0 NEXT-HOP-SELF                  0          0                    0
# 5   losa-re0 NEXT-HOP-SELF                  0          0                    0
# 6   newy-re0 NEXT-HOP-SELF                  0          0                    0
# 7   salt-re0 NEXT-HOP-SELF                  0          0                    0
# 8   seat-re0 NEXT-HOP-SELF                  0          0                    0
# 9   wash-re0 NEXT-HOP-SELF                  0          0                    0
# 10                   TOTAL                  0          0                    0
#
#    Local_Preference
# ...
